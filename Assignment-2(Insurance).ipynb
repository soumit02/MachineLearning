# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df=pd.read_excel("insurance.xlsx")

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.isnull().sum()
# Out:
# age         0
# gender      0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# # Handle the Null value

# %%
Mean_bmi=df.bmi.mean()

# %%
df.bmi=df.bmi.fillna(Mean_bmi)
df.isnull().sum()
# Out:
# age         0
# gender      0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df1 = df.copy()
df2=df.copy()
df3=df.copy()
df4=df.copy()
df5=df.copy()
df6=df.copy()
df7=df.copy()
df8=df.copy()
df9=df.copy()
df10=df.copy()
df11=df.copy()
df12=df.copy()
df13=df.copy()
df14=df.copy()
df15=df.copy()

# %% [markdown]
# # Without Encoding(Replacement Method)

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # gender

# %%
gender=df.gender.unique()
gender
# Out:
# array(['female', 'male'], dtype=object)

# %%
df.gender=df.gender.replace(['female', 'male'],[0,1])

# %%
df.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19       0  27.900         0    yes  southwest  16884.92400
# 1   18       1  33.770         1     no  southeast   1725.55230
# 2   28       1  33.000         3     no  southeast   4449.46200
# 3   33       1  22.705         0     no  northwest  21984.47061
# 4   32       1  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # smoker

# %%
smoker=df.smoker.unique()
smoker
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df.smoker=df.smoker.replace(['yes', 'no'],[1,0])

# %%
df.head()
# Out:
#    age  gender     bmi  children  smoker     region      charges
# 0   19       0  27.900         0       1  southwest  16884.92400
# 1   18       1  33.770         1       0  southeast   1725.55230
# 2   28       1  33.000         3       0  southeast   4449.46200
# 3   33       1  22.705         0       0  northwest  21984.47061
# 4   32       1  28.880         0       0  northwest   3866.85520

# %% [markdown]
# # region

# %%
region=df.region.unique()
region
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
df.region=df.region.replace(['southwest', 'southeast', 'northwest', 'northeast'],[0,1,2,3])

# %%
df.head(10)
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0   19       0  27.900         0       1       0  16884.92400
# 1   18       1  33.770         1       0       1   1725.55230
# 2   28       1  33.000         3       0       1   4449.46200
# 3   33       1  22.705         0       0       2  21984.47061
# 4   32       1  28.880         0       0       2   3866.85520
# 5   31       0  25.740         0       0       1   3756.62160
# 6   46       0  33.440         1       0       1   8240.58960
# 7   37       0  27.740         3       0       2   7281.50560
# 8   37       1  29.830         2       0       3   6406.41070
# 9   60       0  25.840         0       0       2  28923.13692

# %% [markdown]
# # Label Encoder(Without Loop)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb=LabelEncoder()

# %%
df1.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df1.gender=lb.fit_transform(df1.gender)
df1.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19       0  27.900         0    yes  southwest  16884.92400
# 1   18       1  33.770         1     no  southeast   1725.55230
# 2   28       1  33.000         3     no  southeast   4449.46200
# 3   33       1  22.705         0     no  northwest  21984.47061
# 4   32       1  28.880         0     no  northwest   3866.85520

# %%
df1.smoker=lb.fit_transform(df1.smoker)
df1.region=lb.fit_transform(df1.region)
df1.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0   19       0  27.900         0       1       3  16884.92400
# 1   18       1  33.770         1       0       2   1725.55230
# 2   28       1  33.000         3       0       2   4449.46200
# 3   33       1  22.705         0       0       1  21984.47061
# 4   32       1  28.880         0       0       1   3866.85520

# %% [markdown]
# # Label Encoding(With Loop)

# %%
df2.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
for i in df2.columns:
    if df2[i].dtype==np.number:
        continue
    else:
        df2[i]=lb.fit_transform(df2[i])
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16516\2392410711.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df2[i].dtype==np.number:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16516\2392410711.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df2[i].dtype==np.number:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16516\2392410711.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df2[i].dtype==np.number:
# C:\Users\USER\AppData\Local\Temp\ipykernel_16516\2392410711.py:2: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if df2[i].dtype==np.number:
# ...

# %%
df2.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0    1       0  27.900         0       1       3  16884.92400
# 1    0       1  33.770         1       0       2   1725.55230
# 2   10       1  33.000         3       0       2   4449.46200
# 3   15       1  22.705         0       0       1  21984.47061
# 4   14       1  28.880         0       0       1   3866.85520

# %%
df3.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from pandas.core.dtypes.common import is_numeric_dtype

# %%
for i in df3.columns:
    if is_numeric_dtype(df3[i]):
        continue
    else:
        df3[i]=lb.fit_transform(df3[i])

# %%
df3.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0   19       0  27.900         0       1       3  16884.92400
# 1   18       1  33.770         1       0       2   1725.55230
# 2   28       1  33.000         3       0       2   4449.46200
# 3   33       1  22.705         0       0       1  21984.47061
# 4   32       1  28.880         0       0       1   3866.85520

# %% [markdown]
# # One  Hot Encoding(Without Loop)

# %%
df4.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # gender

# %%
dummy=pd.get_dummies(df4.gender,columns=df4.gender.unique(),dtype=int)
dummy.head()
# Out:
#    female  male
# 0       1     0
# 1       0     1
# 2       0     1
# 3       0     1
# 4       0     1

# %%
df4.drop("gender",axis=1,inplace=True)
df4.head()
# Out:
#    age     bmi  children smoker     region      charges
# 0   19  27.900         0    yes  southwest  16884.92400
# 1   18  33.770         1     no  southeast   1725.55230
# 2   28  33.000         3     no  southeast   4449.46200
# 3   33  22.705         0     no  northwest  21984.47061
# 4   32  28.880         0     no  northwest   3866.85520

# %%
dummy=pd.get_dummies(df5.gender,columns=df5.gender.unique(),drop_first=True,prefix="gender",dtype=int)
dummy.head()
# Out:
#    gender_male
# 0            0
# 1            1
# 2            1
# 3            1
# 4            1

# %%
df6=pd.concat([df4,dummy],axis=1)
df6.head()
# Out:
#    age     bmi  children smoker     region      charges  gender_male
# 0   19  27.900         0    yes  southwest  16884.92400            0
# 1   18  33.770         1     no  southeast   1725.55230            1
# 2   28  33.000         3     no  southeast   4449.46200            1
# 3   33  22.705         0     no  northwest  21984.47061            1
# 4   32  28.880         0     no  northwest   3866.85520            1

# %% [markdown]
# # smoker

# %%
df6.drop('smoker',axis=1,inplace=True)

# %%
df6.head()
# Out:
#    age     bmi  children     region      charges  gender_male
# 0   19  27.900         0  southwest  16884.92400            0
# 1   18  33.770         1  southeast   1725.55230            1
# 2   28  33.000         3  southeast   4449.46200            1
# 3   33  22.705         0  northwest  21984.47061            1
# 4   32  28.880         0  northwest   3866.85520            1

# %%
dummy=pd.get_dummies(df7.smoker,columns=df7.smoker.unique(),drop_first=True,prefix="smoker",dtype=int)
dummy.head()
# Out:
#    smoker_yes
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0

# %%
df8=pd.concat([df6,dummy],axis=1)
df8.head()
# Out:
#    age     bmi  children     region      charges  gender_male  smoker_yes
# 0   19  27.900         0  southwest  16884.92400            0           1
# 1   18  33.770         1  southeast   1725.55230            1           0
# 2   28  33.000         3  southeast   4449.46200            1           0
# 3   33  22.705         0  northwest  21984.47061            1           0
# 4   32  28.880         0  northwest   3866.85520            1           0

# %% [markdown]
# # region

# %%
df8.drop("region",axis=1,inplace=True)

# %%
df8.head()
# Out:
#    age     bmi  children      charges  gender_male  smoker_yes
# 0   19  27.900         0  16884.92400            0           1
# 1   18  33.770         1   1725.55230            1           0
# 2   28  33.000         3   4449.46200            1           0
# 3   33  22.705         0  21984.47061            1           0
# 4   32  28.880         0   3866.85520            1           0

# %%
dummy=pd.get_dummies(df9.region,columns=df9.region.unique(),drop_first=True,prefix="region",dtype=int)

# %%
dummy.head()
# Out:
#    region_northwest  region_southeast  region_southwest
# 0                 0                 0                 1
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 1                 0                 0
# 4                 1                 0                 0

# %%
df10=pd.concat([df8,dummy],axis=1)

# %%
df10.head()
# Out:
#    age     bmi  children      charges  gender_male  smoker_yes  \
# 0   19  27.900         0  16884.92400            0           1
# 1   18  33.770         1   1725.55230            1           0
# 2   28  33.000         3   4449.46200            1           0
# 3   33  22.705         0  21984.47061            1           0
# 4   32  28.880         0   3866.85520            1           0
#
#    region_northwest  region_southeast  region_southwest
# 0                 0                 0                 1
# 1                 0                 1                 0
# 2                 0                 1                 0
# 3                 1                 0                 0
# 4                 1                 0                 0

# %% [markdown]
# # One Hot Encoding(With Loop)

# %%
df11.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
#cols=["gender","smoker","region"]
for col in df11.columns:
    if df11[col].dtype=='object':
        dummy=pd.get_dummies(df11[col],drop_first=True,dtype=int)
        df12=pd.concat([df11,dummy],axis=1).drop(col,axis=1)

# %%
df12.head()
# Out:
#    age  gender     bmi  children smoker      charges  northwest  southeast  \
# 0   19  female  27.900         0    yes  16884.92400          0          0
# 1   18    male  33.770         1     no   1725.55230          0          1
# 2   28    male  33.000         3     no   4449.46200          0          1
# 3   33    male  22.705         0     no  21984.47061          1          0
# 4   32    male  28.880         0     no   3866.85520          1          0
#
#    southwest
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %% [markdown]
# # Ordinal Encoding (Without Loop)

# %%
df13.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# # gender

# %%
gender=df13.gender.unique()
gender
# Out:
# array(['female', 'male'], dtype=object)

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
od=OrdinalEncoder(categories=[gender])

# %%
encoded_values=od.fit_transform(df13[["gender"]])

# %%
encoded_values
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        ...,
#        [0.],
#        [0.],
#        [0.]])

# %%
encoded_values=pd.DataFrame(encoded_values,columns=["gender"])
encoded_values.head()
# Out:
#    gender
# 0     0.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0

# %%
df13=pd.concat([df13.drop("gender",axis=1),encoded_values],axis=1)

# %%
df13.head()
# Out:
#    age     bmi  children smoker     region      charges  gender
# 0   19  27.900         0    yes  southwest  16884.92400     0.0
# 1   18  33.770         1     no  southeast   1725.55230     1.0
# 2   28  33.000         3     no  southeast   4449.46200     1.0
# 3   33  22.705         0     no  northwest  21984.47061     1.0
# 4   32  28.880         0     no  northwest   3866.85520     1.0

# %% [markdown]
# # smoker

# %%
smoker=df13.smoker.unique()
smoker
# Out:
# array(['yes', 'no'], dtype=object)

# %%
#from sklearn.preprocessing import OrdinalEncoder

# %%
oi=OrdinalEncoder(categories=[smoker])

# %%
encoded_attribute=oi.fit_transform(df13[["smoker"]])

# %%
encoded_attribute
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        ...,
#        [1.],
#        [1.],
#        [0.]])

# %%
encoded_attribute=pd.DataFrame(encoded_attribute,columns=["smoker"])
encoded_attribute.head()
# Out:
#    smoker
# 0     0.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0

# %%
df13=pd.concat([df13.drop("smoker",axis=1),encoded_attribute],axis=1)

# %%
df13.head()
# Out:
#    age     bmi  children     region      charges  gender  smoker
# 0   19  27.900         0  southwest  16884.92400     0.0     0.0
# 1   18  33.770         1  southeast   1725.55230     1.0     1.0
# 2   28  33.000         3  southeast   4449.46200     1.0     1.0
# 3   33  22.705         0  northwest  21984.47061     1.0     1.0
# 4   32  28.880         0  northwest   3866.85520     1.0     1.0

# %% [markdown]
# # region

# %%
region=df13.region.unique()
region
# Out:
# array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)

# %%
ol=OrdinalEncoder(categories=[region])

# %%
encoded_values1=ol.fit_transform(df13[["region"]])

# %%
encoded_values1
# Out:
# array([[0.],
#        [1.],
#        [1.],
#        ...,
#        [1.],
#        [0.],
#        [2.]])

# %%
encoded_values1=pd.DataFrame(encoded_values1,columns=["region"])
encoded_values1.head(10)
# Out:
#    region
# 0     0.0
# 1     1.0
# 2     1.0
# 3     2.0
# 4     2.0
# 5     1.0
# 6     1.0
# 7     2.0
# 8     3.0
# 9     2.0

# %%
df13=pd.concat([df13.drop("region",axis=1),encoded_values1],axis=1)

# %%
df13.head()
# Out:
#    age     bmi  children      charges  gender  smoker  region
# 0   19  27.900         0  16884.92400     0.0     0.0     0.0
# 1   18  33.770         1   1725.55230     1.0     1.0     1.0
# 2   28  33.000         3   4449.46200     1.0     1.0     1.0
# 3   33  22.705         0  21984.47061     1.0     1.0     2.0
# 4   32  28.880         0   3866.85520     1.0     1.0     2.0

# %% [markdown]
# # Ordinal Encoding(With Loop)

# %%
df14.head()
# Out:
#    age  gender     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
for i in df14.columns:
    if df14[i].dtype=='object':
        ob=OrdinalEncoder()
        encoded_values2=ob.fit_transform(df14[[i]])
        df14[i]= encoded_values2.flatten()

# %%
df14.head()
# Out:
#    age  gender     bmi  children  smoker  region      charges
# 0   19     0.0  27.900         0     1.0     3.0  16884.92400
# 1   18     1.0  33.770         1     0.0     2.0   1725.55230
# 2   28     1.0  33.000         3     0.0     2.0   4449.46200
# 3   33     1.0  22.705         0     0.0     1.0  21984.47061
# 4   32     1.0  28.880         0     0.0     1.0   3866.85520
